# %% [markdown]
# ### 1.Calculate the 95% confidence interval for a sample mean of 40 and sample standard deviation of 40 with sample size equal to 100.

# %%
import numpy as np 
import pandas as pd

# %%
x=40
sd=40
CI=95
alpha=0.05
n=100
z=1.96

# %%
MOE=z*(sd/np.sqrt(n))

# %%
MOE
# Out:
# 7.84

# %%
lower_CI=x-MOE
upper_CI=x+MOE

# %%
print(lower_CI)
print(x)
print(upper_CI)
# Out:
# 32.16
# 40
# 47.84

# %% [markdown]
# ![WhatsApp%20Image%202024-01-06%20at%2010.20.24_768878eb.jpg](attachment:WhatsApp%20Image%202024-01-06%20at%2010.20.24_768878eb.jpg)

# %% [markdown]
# ### 2.A population has a mean weight of 68 kg. A random sample of size 25 has a mean weight of 70 with standard deviation =4. Identify whether this sample is representative of the population.

# %%
u=68
n=25
x=70
SD=4

# H0= sample is representative of the population;
# H1=sample is not representative of the population;

# %%
t=(x-u)/(SD/np.sqrt(n))
print(t)
# Out:
# 2.5

# %% [markdown]
# - Critical value for for aplha=0.05 is 2.064
#  - t-value is greater than critical value so reject the null hypothesis.

# %% [markdown]
# ![WhatsApp%20Image%202024-01-06%20at%2010.36.45_8374912d.jpg](attachment:WhatsApp%20Image%202024-01-06%20at%2010.36.45_8374912d.jpg)

# %% [markdown]
# #### 3.Suppose there are 3 chocolates in town and their sweetness is quantified by some metric (S). Data is collected on the three chocolates. You are given the task to identify whether the mean sweetness of the 3 chocolates are different. The data is given as below:

# %% [markdown]
# ![WhatsApp%20Image%202024-01-06%20at%2010.20.25_c8fd5589.jpg](attachment:WhatsApp%20Image%202024-01-06%20at%2010.20.25_c8fd5589.jpg)

# %% [markdown]
# ![WhatsApp%20Image%202024-01-06%20at%2010.20.25_7b4c22c8.jpg](attachment:WhatsApp%20Image%202024-01-06%20at%2010.20.25_7b4c22c8.jpg)
